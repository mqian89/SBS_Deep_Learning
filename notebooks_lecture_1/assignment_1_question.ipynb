# %% [markdown]
# # Assignment 1

# %% [markdown]
# In this assignment you predict the total number of daily online job ads in the United Kingdom. Every day tens of thousand of new jobs are advertised online in the United Kingdom, including a growing number of machine learning jobs. We use job counts from the 30 cities with the highest number of job ads posted as features. Both the total job count and the city job count are for the same day, so the exercise is an interpolation exercise and not time-series forecasting.

# %% [markdown]
# The dataset we use is called 'bg_job_counts_train.csv'. The first column in the date. The second column contains the output variable, which is the total number of job ads posted on that day in the UK. The subsequent columns contain the number of jobs by city.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.read_csv('bg_job_counts_train.csv', index_col = 0).head(10)
# Out:
#       JobDate  Job Count  aberdeen  basildon  basingstoke  bedford  \
# 0  2012-01-01      13983     152.0      31.0         80.0     29.0
# 1  2012-01-02       4822      17.0       7.0         15.0     34.0
# 2  2012-01-03      15518     585.0      37.0         29.0     23.0
# 3  2012-01-04      18085     250.0      65.0         41.0     91.0
# 4  2012-01-05      20922     248.0      69.0        256.0     66.0
# 5  2012-01-06      12188     174.0     685.0         31.0   1063.0
# 6  2012-01-07       8281     119.0       5.0         20.0     27.0
# 7  2012-01-08       8801      84.0      10.0         44.0     69.0
# 8  2012-01-09      11575     314.0      32.0         61.0     18.0
# 9  2012-01-10      11408     201.0      18.0         48.0     17.0
#
#    birmingham  bristol  cambridge  carlisle  colchester  coventry  doncaster  \
# 0       300.0    319.0      308.0      11.0        71.0      93.0      124.0
# ...

# %% [markdown]
# We will evaluate your models that you build in a competition.

# %% [markdown]
# Each team can submit three models into the competition. The models are then evaluated based upon the HY2 of 2019 and the data for 2020. We have two evaluation datasets. They will be called 'bg_job_counts_test1.csv' and 'bg_job_counts_test2.csv'.

# %% [markdown]
# Your goal is to have the best mean absolute error on each of the two test datasets. It can be different models which achieve the goal. Note that in 2020, we have a huge structural break, which is the COVID-19 pandemic.

# %% [markdown]
# Each team will present their models next week within the last 45 minutes of the class. Each team gets around 8 minutes. I'll share with the team the link to the dataset just before their presentation, so that they cannot modify the models to get an advantage. Please have to code and models ready for deployment on the evaluation dataset, which has the same structure as the training data.

# %% [markdown]
# # Good Luck!
